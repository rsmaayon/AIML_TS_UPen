# %% [markdown]
# # Assignment 1: Exploratory Data Analysis

# %% [markdown]
# ## Imports
# It is important for all (or most) imports to go on the top of a notebook so that other users know which packages need to be installed. In projects that use Anaconda, it is also common to see a file named requirements.txt listing all the packages that one has to install.
#
# First, let's import all the necessary modules using the import function. For this exercise, we will be mainly using pandas but you will also gain some experience with numpy, seaborn, and matplotlib.
#
# To learn more about these packages, you can read through the documentation:
# https://pandas.pydata.org/
# https://numpy.org/
# https://seaborn.pydata.org/
# https://matplotlib.org/

# %%
# Let's import the relevant Python packages here
# Feel free to import any other packages for this project

#Data Wrangling
import numpy as np
import pandas as pd

#Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Data
# In the following exercise, we will familiarize ourselves with Python by studying the College dataset, which can be found in the file College.csv. This dataset contains the following variables from 777 different universities and colleges in the US. Just try to skim through the table to get an idea of all the datapoints we are provided with.
#
# | Column | Description |
# |:-|:-|
# |Private | Public/private indicator|
# |Apps | Number of applications received|
# |Accept | Number of applicants accepted|
# |Enroll | Number of new students enrolled|
# |Top10perc | New students from top 10\% of high school class|
# |Top25perc | New students from top 25\% of high school class|
# |F.Undergrad | Number of full-time undergraduates|
# |P.Undergrad | Number of part-time undergraduates|
# |Outstate | Out-of-state tuition|
# |Room.Board | Room and board costs|
# |Books | Estimated book costs|
# |Personal | Estimated personal spending|
# |PhD | Percent of faculty with Ph.D.’s|
# |Terminal | Percent of faculty with terminal degree|
# |S.F.Ratio | Student/faculty ratio|
# |Perc.alumni | Percent of alumni who donate|
# |Expend | Instructional expenditure per student|
# |Grad.Rate | Graduation rate|

# %% [markdown]
# Load the College dataset using pandas

# %%
college = pd.read_csv("College.csv")

# Renaming a few columns for readability 
college = college.rename(columns = {'Grad.Rate':'Grad_Rate',
                              'S.F.Ratio': 'S_F_Ratio',
                              'perc.alumni':'perc_alumni',
                              'Room.Board':'Room_Board',
                              'F.Undergrad':'F_Undergrad',
                              'P.Undergrad':'P_Undergrad'})

# %% [markdown]
# 1. Use the head() function to view a few rows in the data.

# %%
# Try to use head() on 'college' and observe the output

# your code here
college.head()
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F_Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    P_Undergrad  Outstate  Room_Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    S_F_Ratio  perc_alumni  Expend  Grad_Rate                         Names
# ...

# %% [markdown]
# Notice that there is a column ‘Names’ of each university’s name. As we don’t want to use these names as predictors, they are natural candidates to index our data. Indexing simply means using these college names to represent the corresponding row in our data, instead of serial numbers. We can do this using the following function.

# %%
college.set_index('Names', inplace = True)

# %% [markdown]
# Let's use the head() function again. You should now see that the indices have been replaced with the name of each university in the data set. This means that Python has given each row a name corresponding to the appropriate university. Python will not try to perform calculations on the row names.

# %%
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Names
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F_Undergrad  P_Undergrad  Outstate  \
# Names
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# 2. Use the info() function to check and produce a numerical summary of your variables.

# %%
# Try to use info() for 'college'and skim through the result

# your code here
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    object
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F_Undergrad  777 non-null    int64
#  7   P_Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room_Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S_F_Ratio    777 non-null    float64
#  15  perc_alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
# ...

# %% [markdown]
# 3. Examine if there are any duplicates and drop them if needed. Drop them "in place".
#
# Hint 1: It is perfectly fine to observe no duplicates in the dataset, but it is good practice to check anyhow. Before dropping duplicates, it is also good practice to check whether the duplicates contained any different data, since data entry errors frequently occur.
#
# Hint 2: Check for "inplace" argument in the drop duplicates documentation

# %%
# Modify 'college' inplace to drop duplicates inplace

# your code here
college.drop_duplicates(inplace=True)

college.info() #check again
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    object
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F_Undergrad  777 non-null    int64
#  7   P_Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room_Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S_F_Ratio    777 non-null    float64
#  15  perc_alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
# ...

# %% [markdown]
# 4. Replace any missing values in the 'Apps' column with 0. This dataframe will henceforth be our original dataframe.
#
# Hint: Na means no value, NaN means Not a Number. It is perfectly fine if there are no Na's in our dataset, but we should always check just in case.

# %%
# Modify 'college' inplace to replace any missing values in the 'Apps' column with 0

# your code here
college.isnull().sum()
# Out:
# Private        0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F_Undergrad    0
# P_Undergrad    0
# Outstate       0
# Room_Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S_F_Ratio      0
# perc_alumni    0
# Expend         0
# Grad_Rate      0
# dtype: int64

# %%
college.Apps.value_counts()
# Out:
# 663     3
# 1006    3
# 440     3
# 1660    2
# 232     2
#        ..
# 8681    1
# 3050    1
# 268     1
# 5659    1
# 2989    1
# Name: Apps, Length: 711, dtype: int64

# %%
college[college['Apps'] == 0]
# Out:
# Empty DataFrame
# Columns: [Private, Apps, Accept, Enroll, Top10perc, Top25perc, F_Undergrad, P_Undergrad, Outstate, Room_Board, Books, Personal, PhD, Terminal, S_F_Ratio, perc_alumni, Expend, Grad_Rate]
# Index: []

# %%
##########################
### TEST YOUR SOLUTION ###
##########################

assert college[college['Apps'] == 0].empty, "Filtered colleges for those with 0 apps dataframe should be empty.."

# %% [markdown]
# 5. Find the college with the least out-of-state tuition and name this variable `college_least_tuition`. The variable should return the name of a college, not its tuition.

# %%
college_least_tuition = college["Outstate"].idxmin()
college_least_tuition
# Out:
# 'Brigham Young University at Provo'

# %%
##########################
### TEST YOUR SOLUTION ###
##########################

assert college_least_tuition == "Brigham Young University at Provo", "college_least_tuition is wrong, try again.."

# %% [markdown]
# 6. From the original dataframe, select the ‘PhD’ column and name this dataframe phd_column. Find the length of this column and name this variable `phd_column_length`.
#
# Hint: Make sure to use double brackets to select a Pandas dataframe and single brackets to select a Pandas series. You will notice the difference in formatting: Pandas dataframes are neatly formatted, while Pandas series are not formatted. A Pandas dataframe gives extra functionality compared to a Pandas series, such as appending other dataframes and selecting multiple columns. A Pandas series is essentially a Numpy column.

# %%
# Double bracket for dataframe

phd_column = college[["PhD"]]

# your code here
phd_column
# Out:
#                                 PhD
# Names
# Abilene Christian University     70
# Adelphi University               29
# Adrian College                   53
# Agnes Scott College              92
# Alaska Pacific University        76
# ...                             ...
# Worcester State College          60
# Xavier University                73
# Xavier University of Louisiana   67
# Yale University                  96
# York College of Pennsylvania     75
#
# [777 rows x 1 columns]

# %%
##########################
### TEST YOUR SOLUTION ###
##########################

phd_column_length = len(phd_column)
assert phd_column_length==777, "Length of phd_column is wrong, try again.."

# %% [markdown]
# 7. (a) From the original dataframe, select both the ‘Private’ and ‘Top10perc’ columns, and slice them such that only the rows with index 15 and 16 remain. Name this dataframe private_top10.
#
#    (b) From this dataframe, find the length of the filtered ‘Private’ column and name this variable `private_column_length`.

# %%
# Double bracket to obtain multiple columns

private = college[["Private","Top10perc"]]

private

private_top10 = private.iloc[15:17]

private_top10
# Out:
#                                Private  Top10perc
# Names
# American International College     Yes          9
# Amherst College                    Yes         83

# %%
##########################
### TEST YOUR SOLUTION ###
##########################

private_column_length = len(private_top10[['Private']])
assert private_column_length == 2, "Length of private_top10 is wrong, try again.."

# %% [markdown]
# From the original dataframe, select the row that only contains data about the “University of Pennsylvania”. Note that many other colleges share the same name, but there is only one unique University of Pennsylvania. Name this dataframe penn.

# %%
penn = college.loc[['University of Pennsylvania']]
penn
# Out:
#                            Private   Apps  Accept  Enroll  Top10perc  \
# Names
# University of Pennsylvania     Yes  12394    5232    2464         85
#
#                             Top25perc  F_Undergrad  P_Undergrad  Outstate  \
# Names
# University of Pennsylvania        100         9205          531     17020
#
#                             Room_Board  Books  Personal  PhD  Terminal  \
# Names
# University of Pennsylvania        7270    500      1544   95        96
#
#                             S_F_Ratio  perc_alumni  Expend  Grad_Rate
# Names
# University of Pennsylvania        6.3           38   25765         93

# %% [markdown]
# 8. From the original dataframe, select the rows that contain all colleges with the name “Penn” included. The “P” in Penn should be capitalized. Name this dataframe `many_penns`.

# %%
many_penns = None # Save your solution in this variable
many_penns = college[college.index.str.contains("Penn")]


many_penns
# Out:
#                                       Private   Apps  Accept  Enroll  \
# Names
# Bloomsburg Univ. of Pennsylvania           No   6773    3028    1025
# Lock Haven University of Pennsylvania      No   3570    2215     651
# Millersville University of Penn.           No   6011    3075     960
# Pennsylvania State Univ. Main Campus       No  19315   10344    3450
# Shippensburg University of Penn.           No   5818    3281    1116
# University of Pennsylvania                Yes  12394    5232    2464
# West Chester University of Penn.           No   6502    3539    1372
# York College of Pennsylvania              Yes   2989    1855     691
#
#                                        Top10perc  Top25perc  F_Undergrad  \
# Names
# Bloomsburg Univ. of Pennsylvania              15         55         5847
# Lock Haven University of Pennsylvania         17         41         3390
# Millersville University of Penn.              22         60         5146
# ...

# %%
##########################
### TEST YOUR SOLUTION ###
##########################

assert many_penns.index.str.contains("Penn").all(), "Values in many_penns is wrong, try again.."
assert len(many_penns) == 8, "Length of many_penns is wrong, try again.."

# %% [markdown]
# 9. Use the `seaborn` `pairplot()` function on the original dataframe with all universities to produce a scatterplot matrix of the ﬁrst ten columns of the data.

# %%
# your code here
sns.pairplot(data=college.iloc[:, :10])
plt.show()

# %% [markdown]
# 10. Use the `seaborn` `boxplot()` function on the original dataframe with all universities to produce side-by-side box plots of ‘Outstate’ versus ‘Private’. Find the average out of state tuition at private universities and name this variable`private`. Find the average out of state tuition at public universities and name this variable `public`. An approximate solution for both is fine!

# %%
privateselect = college[college["Private"] == "Yes"] # Save your solution in this variable
privateselect

private = privateselect["Outstate"].mean()
private

publicselect = college[college["Private"] == "No"]
public = publicselect["Outstate"].mean()
public
# Out:
# 6813.41037735849

# %%
# ##########################
# ### TEST YOUR SOLUTION ###
# ##########################
assert np.allclose(private, 11000, 1000), "Value for private is wrong, try again.."
assert np.allclose(public, 6000, 1000), "Value for public is wrong, try again.."

# %% [markdown]
# 11. Create a new qualitative variable named `large_university` by binning the ‘Enroll’ column. We are going to divide universities into two groups based on whether the number of new students enrolled exceeds the average (mean) of all new students enrolled.  Hint: The variable `large_university` is an indicator variable (a Pandas series that represents a series of booleans, a list is also acceptable). In Python, this is called a "mask," which you can later manipulate to slice your data.

# %%
mean_enroll = college['Enroll'].mean()
mean_enroll

college['large_university'] = [1 if x > mean_enroll else 0 for x in college['Enroll']]
college['large_university']
# Out:
# Names
# Abilene Christian University      0
# Adelphi University                0
# Adrian College                    0
# Agnes Scott College               0
# Alaska Pacific University         0
#                                  ..
# Worcester State College           0
# Xavier University                 0
# Xavier University of Louisiana    0
# Yale University                   1
# York College of Pennsylvania      0
# Name: large_university, Length: 777, dtype: int64

# %% [markdown]
# 12. Create a dataframe called `large_universities` that only includes large universities.

# %%
large_universities = college[college['large_university'] == 1]
# your code here

large_universities.head()
# Out:
#                                      Private   Apps  Accept  Enroll  \
# Names
# Angelo State University                   No   3540    2001    1016
# Appalachian State University              No   7313    4664    1910
# Arizona State University Main campus      No  12809   10308    3761
# Arkansas Tech University                  No   1734    1729     951
# Auburn University-Main Campus             No   7548    6791    3070
#
#                                       Top10perc  Top25perc  F_Undergrad  \
# Names
# Angelo State University                      24         54         4190
# Appalachian State University                 20         63         9940
# Arizona State University Main campus         24         49        22593
# Arkansas Tech University                     12         52         3602
# Auburn University-Main Campus                25         57        16262
#
#                                       P_Undergrad  Outstate  Room_Board  \
# Names
# ...

# %% [markdown]
# 13. Use the `pandas` `describe(include = ‘all’)` function on large_universities to produce a numerical summary of each column. Within this dataframe, find the $75^{th}$ percentile for the column ‘Enroll’ and name this variable `enroll`.

# %%
college.describe(include = 'all')

enroll = np.percentile(large_universities.Enroll, 75)

enroll
# Out:
# 2408.0

# %%
# ##########################
# ### TEST YOUR SOLUTION ###
# ##########################
assert np.allclose(enroll, 2408.0, .01), "Value for enroll is wrong, try again.."

# %% [markdown]
# 14. Use `matplotlib.pyplot.hist()` or `seaborn.distplot()` to create a histogram to examine the number of applications received with a bin size of 200. Use your histogram to answer the following question. Is it true that more universities receive 0 to 10,000 applications than 10,000 to 20,000 applications? Store your answer in a variable named `applications`.

# %%
plt.figure(figsize=(10,5))
sns.displot(data=college.Apps, bins=200)

plt.show()

# %%
applications = None # Save your solution in this variable
# your code here
applications = True

# %%
# ##########################
# ### TEST YOUR SOLUTION ###
# ##########################
assert applications == True, "Value for applications is wrong, try again.."

# %% [markdown]
# 15. We are interested in the acceptance rate of these universities. To calculate the acceptance rate, we take the ‘Accept’ column and divide by the ‘Apps’ column. Add this column to a copied version of the original dataframe. Remember to copy the dataframe first before performing feature transformation, as we do not wish to alter or inadvertently create new columns in our original data. Name your new column `acceptance_rate` and use your new dataframe to answer the following questions. Which college has the lowest acceptance rate? Which college has the highest acceptance rate? Store your answers in variables named `lowest` and `highest` respectively. If there is a tie, you can pick any university.

# %%
df = college.copy()

# %%
df["AcceptRate"] = df["Accept"]/df["Apps"]

# %%
df.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Names
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F_Undergrad  P_Undergrad  Outstate  \
# Names
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
lowest = df["AcceptRate"].idxmin()
highest = df["AcceptRate"].idxmax()
# your code here
lowest, highest
# Out:
# ('Princeton University', 'Emporia State University')

# %%
print("all tests done")
# Out:
# all tests done

# %%
# ##########################
# ### TEST YOUR SOLUTION ###
# ##########################
assert lowest == "Princeton University", "Value for highest is wrong, try again.."
assert highest in ['Emporia State University', 'Maryville State University', 'MidAmerica Nazarene College', 'Southwest Baptist University', 'University of Wisconsin-Superior', 'Wayne State College'], "Value for lowest is wrong, try again.."

# %%
print("all asserts positive and no error reported")
# Out:
# all asserts positive and no error reported
